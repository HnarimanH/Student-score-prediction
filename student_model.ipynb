# %% [markdown]
# ## Student preformance prediction

# %% [markdown]
# ### Importing necessary libraries

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %% [markdown]
# ### Loading the Dataset

# %%
df = pd.read_csv("student_data.csv")
df
# Out:
#         id first_name last_name                                    email  \
# 0        1       Paul     Casey           paul.casey.1@gslingacademy.com
# 1        2   Danielle  Sandoval    danielle.sandoval.2@gslingacademy.com
# 2        3       Tina   Andrews         tina.andrews.3@gslingacademy.com
# 3        4       Tara     Clark           tara.clark.4@gslingacademy.com
# 4        5    Anthony    Campos       anthony.campos.5@gslingacademy.com
# ...    ...        ...       ...                                      ...
# 1995  1996       Alan  Reynolds     alan.reynolds.1996@gslingacademy.com
# 1996  1997     Thomas   Gilbert    thomas.gilbert.1997@gslingacademy.com
# 1997  1998    Madison     Cross     madison.cross.1998@gslingacademy.com
# 1998  1999   Brittany   Compton  brittany.compton.1999@gslingacademy.com
# 1999  2000    Natalie     Smith     natalie.smith.2000@gslingacademy.com
#
#       gender  part_time_job  absence_days  extracurricular_activities  \
# 0       male          False             3                       False
# 1     female          False             2                       False
# 2     female          False             9                        True
# 3     female          False             5                       False
# 4       male          False             5                       False
# ...      ...            ...           ...                         ...
# 1995    male          False             2                       False
# 1996    male          False             2                       False
# 1997  female          False             5                       False
# 1998  female           True            10                        True
# 1999  female          False             5                       False
#
#       weekly_self_study_hours      career_aspiration  math_score  \
# 0                          27                 Lawyer          73
# 1                          47                 Doctor          90
# 2                          13     Government Officer          81
# 3                           3                 Artist          71
# 4                          10                Unknown          84
# ...                       ...                    ...         ...
# 1995                       30  Construction Engineer          83
# 1996                       20      Software Engineer          89
# 1997                       14      Software Engineer          97
# 1998                        5         Business Owner          51
# 1999                       27             Accountant          82
#
#       history_score  physics_score  chemistry_score  biology_score  \
# 0                81             93               97             63
# 1                86             96              100             90
# 2                97             95               96             65
# 3                74             88               80             89
# 4                77             65               65             80
# ...             ...            ...              ...            ...
# 1995             77             84               73             75
# 1996             65             73               80             87
# 1997             85             63               93             68
# 1998             96             72               89             95
# 1999             99             91               69             83
#
#       english_score  geography_score
# 0                80               87
# 1                88               90
# 2                77               94
# 3                63               86
# 4                74               76
# ...             ...              ...
# 1995             84               82
# 1996             67               73
# 1997             94               78
# 1998             88               75
# 1999             93              100
#
# [2000 rows x 17 columns]

# %% [markdown]
# ### Removing Unnecessary Data

# %%
df = df.drop(["id","first_name","last_name","email"], axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   gender                      2000 non-null   object
#  1   part_time_job               2000 non-null   bool
#  2   absence_days                2000 non-null   int64
#  3   extracurricular_activities  2000 non-null   bool
#  4   weekly_self_study_hours     2000 non-null   int64
#  5   career_aspiration           2000 non-null   object
#  6   math_score                  2000 non-null   int64
#  7   history_score               2000 non-null   int64
#  8   physics_score               2000 non-null   int64
#  9   chemistry_score             2000 non-null   int64
#  10  biology_score               2000 non-null   int64
#  11  english_score               2000 non-null   int64
#  12  geography_score             2000 non-null   int64
# dtypes: bool(2), int64(9), object(2)
# memory usage: 175.9+ KB

# %% [markdown]
# ### Changing (part_time_job , extracurricular_activities) to 1,0

# %%
df["part_time_job"] = df["part_time_job"].map({True: 1, False: 0})
df["extracurricular_activities"] = df["extracurricular_activities"].map({True: 1, False: 0})
df["gender"] = df["gender"].map({"male": 1, "female": 0})
df
# Out:
#       gender  part_time_job  absence_days  extracurricular_activities  \
# 0          1              0             3                           0
# 1          0              0             2                           0
# 2          0              0             9                           1
# 3          0              0             5                           0
# 4          1              0             5                           0
# ...      ...            ...           ...                         ...
# 1995       1              0             2                           0
# 1996       1              0             2                           0
# 1997       0              0             5                           0
# 1998       0              1            10                           1
# 1999       0              0             5                           0
#
#       weekly_self_study_hours      career_aspiration  math_score  \
# 0                          27                 Lawyer          73
# 1                          47                 Doctor          90
# 2                          13     Government Officer          81
# 3                           3                 Artist          71
# 4                          10                Unknown          84
# ...                       ...                    ...         ...
# 1995                       30  Construction Engineer          83
# 1996                       20      Software Engineer          89
# 1997                       14      Software Engineer          97
# 1998                        5         Business Owner          51
# 1999                       27             Accountant          82
#
#       history_score  physics_score  chemistry_score  biology_score  \
# 0                81             93               97             63
# 1                86             96              100             90
# 2                97             95               96             65
# 3                74             88               80             89
# 4                77             65               65             80
# ...             ...            ...              ...            ...
# 1995             77             84               73             75
# 1996             65             73               80             87
# 1997             85             63               93             68
# 1998             96             72               89             95
# 1999             99             91               69             83
#
#       english_score  geography_score
# 0                80               87
# 1                88               90
# 2                77               94
# 3                63               86
# 4                74               76
# ...             ...              ...
# 1995             84               82
# 1996             67               73
# 1997             94               78
# 1998             88               75
# 1999             93              100
#
# [2000 rows x 13 columns]

# %% [markdown]
# ### One Hot Encoding (career_aspiration)

# %%
ohe = OneHotEncoder(handle_unknown='ignore', sparse_output=False).set_output(transform='pandas')
data = ohe.fit_transform((df[["career_aspiration"]]))
df = df.sort_values(by=["career_aspiration"],ascending=1)
df = pd.concat([df, data], axis=1 ).drop(columns=['career_aspiration'])
df
# this cell made the code 60% more acurate!
# Out:
#       gender  part_time_job  absence_days  extracurricular_activities  \
# 1999       0              0             5                           0
# 416        0              0             4                           0
# 422        0              0             4                           0
# 1635       1              0             3                           0
# 444        0              0             3                           0
# ...      ...            ...           ...                         ...
# 1366       1              0             1                           0
# 1568       1              0             5                           0
# 1559       1              0             1                           0
# 1260       1              0             2                           0
# 1497       1              0             7                           0
#
#       weekly_self_study_hours  math_score  history_score  physics_score  \
# 1999                       27          82             99             91
# 416                        30          95             78             93
# 422                        15          79             79             97
# 1635                       27          96             64             76
# 444                        32          83             69             90
# ...                       ...         ...            ...            ...
# 1366                       18          83             96             72
# 1568                       25          73             94             74
# 1559                       32          65             89             70
# 1260                       16          70             75             79
# 1497                       23          70             91             81
#
#       chemistry_score  biology_score  ...  career_aspiration_Game Developer  \
# 1999               69             83  ...                               0.0
# 416                85             48  ...                               0.0
# 422                78             31  ...                               0.0
# 1635               97             81  ...                               0.0
# 444                78             39  ...                               0.0
# ...               ...            ...  ...                               ...
# 1366               81             86  ...                               0.0
# 1568               72             80  ...                               0.0
# 1559               71             74  ...                               0.0
# 1260               77             65  ...                               0.0
# 1497               61             64  ...                               0.0
#
#       career_aspiration_Government Officer  career_aspiration_Lawyer  \
# 1999                                   0.0                       0.0
# 416                                    0.0                       0.0
# 422                                    0.0                       0.0
# 1635                                   0.0                       0.0
# 444                                    0.0                       0.0
# ...                                    ...                       ...
# 1366                                   0.0                       0.0
# 1568                                   0.0                       0.0
# 1559                                   0.0                       0.0
# 1260                                   0.0                       0.0
# 1497                                   0.0                       0.0
#
#       career_aspiration_Real Estate Developer  career_aspiration_Scientist  \
# 1999                                      0.0                          0.0
# 416                                       0.0                          0.0
# 422                                       0.0                          0.0
# 1635                                      0.0                          0.0
# 444                                       0.0                          0.0
# ...                                       ...                          ...
# 1366                                      0.0                          0.0
# 1568                                      0.0                          0.0
# 1559                                      0.0                          0.0
# 1260                                      0.0                          0.0
# 1497                                      0.0                          0.0
#
#       career_aspiration_Software Engineer  career_aspiration_Stock Investor  \
# 1999                                  0.0                               0.0
# 416                                   0.0                               0.0
# 422                                   0.0                               0.0
# 1635                                  0.0                               0.0
# 444                                   0.0                               0.0
# ...                                   ...                               ...
# 1366                                  0.0                               0.0
# 1568                                  0.0                               0.0
# 1559                                  0.0                               0.0
# 1260                                  0.0                               0.0
# 1497                                  0.0                               0.0
#
#       career_aspiration_Teacher  career_aspiration_Unknown  \
# 1999                        0.0                        0.0
# 416                         0.0                        0.0
# 422                         0.0                        0.0
# 1635                        0.0                        0.0
# 444                         0.0                        0.0
# ...                         ...                        ...
# 1366                        0.0                        0.0
# 1568                        0.0                        0.0
# 1559                        0.0                        0.0
# 1260                        0.0                        0.0
# 1497                        0.0                        0.0
#
#       career_aspiration_Writer
# 1999                       0.0
# 416                        0.0
# 422                        0.0
# 1635                       0.0
# 444                        0.0
# ...                        ...
# 1366                       1.0
# 1568                       1.0
# 1559                       1.0
# 1260                       1.0
# 1497                       1.0
#
# [2000 rows x 29 columns]

# %% [markdown]
# ### Converting students grades to GPA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2000 entries, 1999 to 1497
# Data columns (total 29 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   gender                                   2000 non-null   int64
#  1   part_time_job                            2000 non-null   int64
#  2   absence_days                             2000 non-null   int64
#  3   extracurricular_activities               2000 non-null   int64
#  4   weekly_self_study_hours                  2000 non-null   int64
#  5   math_score                               2000 non-null   int64
#  6   history_score                            2000 non-null   int64
#  7   physics_score                            2000 non-null   int64
#  8   chemistry_score                          2000 non-null   int64
#  9   biology_score                            2000 non-null   int64
#  10  english_score                            2000 non-null   int64
#  11  geography_score                          2000 non-null   int64
#  12  career_aspiration_Accountant             2000 non-null   float64
#  13  career_aspiration_Artist                 2000 non-null   float64
#  14  career_aspiration_Banker                 2000 non-null   float64
#  15  career_aspiration_Business Owner         2000 non-null   float64
#  16  career_aspiration_Construction Engineer  2000 non-null   float64
#  17  career_aspiration_Designer               2000 non-null   float64
#  18  career_aspiration_Doctor                 2000 non-null   float64
#  19  career_aspiration_Game Developer         2000 non-null   float64
#  20  career_aspiration_Government Officer     2000 non-null   float64
#  21  career_aspiration_Lawyer                 2000 non-null   float64
#  22  career_aspiration_Real Estate Developer  2000 non-null   float64
#  23  career_aspiration_Scientist              2000 non-null   float64
#  24  career_aspiration_Software Engineer      2000 non-null   float64
#  25  career_aspiration_Stock Investor         2000 non-null   float64
#  26  career_aspiration_Teacher                2000 non-null   float64
#  27  career_aspiration_Unknown                2000 non-null   float64
#  28  career_aspiration_Writer                 2000 non-null   float64
# dtypes: float64(17), int64(12)
# memory usage: 468.8 KB

# %%
math = df["math_score"]
history = df["history_score"]
physics = df["physics_score"]
chemistery = df["chemistry_score"]
biology = df["biology_score"]
english = df["english_score"]
geography = df["geography_score"]
GPA = []
for i in range(0,2000):
    average = (math[i]+history[i]+physics[i]+chemistery[i]+biology[i]+english[i]+geography[i]) / 7
    GPA.append(round(average, 0))
    average=0
df["GPA"] = GPA

# %% [markdown]
# ### Preparing for AI model

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2000 entries, 1999 to 1497
# Data columns (total 30 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   gender                                   2000 non-null   int64
#  1   part_time_job                            2000 non-null   int64
#  2   absence_days                             2000 non-null   int64
#  3   extracurricular_activities               2000 non-null   int64
#  4   weekly_self_study_hours                  2000 non-null   int64
#  5   math_score                               2000 non-null   int64
#  6   history_score                            2000 non-null   int64
#  7   physics_score                            2000 non-null   int64
#  8   chemistry_score                          2000 non-null   int64
#  9   biology_score                            2000 non-null   int64
#  10  english_score                            2000 non-null   int64
#  11  geography_score                          2000 non-null   int64
#  12  career_aspiration_Accountant             2000 non-null   float64
#  13  career_aspiration_Artist                 2000 non-null   float64
#  14  career_aspiration_Banker                 2000 non-null   float64
#  15  career_aspiration_Business Owner         2000 non-null   float64
#  16  career_aspiration_Construction Engineer  2000 non-null   float64
#  17  career_aspiration_Designer               2000 non-null   float64
#  18  career_aspiration_Doctor                 2000 non-null   float64
#  19  career_aspiration_Game Developer         2000 non-null   float64
#  20  career_aspiration_Government Officer     2000 non-null   float64
#  21  career_aspiration_Lawyer                 2000 non-null   float64
#  22  career_aspiration_Real Estate Developer  2000 non-null   float64
#  23  career_aspiration_Scientist              2000 non-null   float64
#  24  career_aspiration_Software Engineer      2000 non-null   float64
#  25  career_aspiration_Stock Investor         2000 non-null   float64
#  26  career_aspiration_Teacher                2000 non-null   float64
#  27  career_aspiration_Unknown                2000 non-null   float64
#  28  career_aspiration_Writer                 2000 non-null   float64
#  29  GPA                                      2000 non-null   float64
# dtypes: float64(18), int64(12)
# memory usage: 548.9 KB

# %%
X = df.drop(["GPA","math_score","history_score","physics_score","biology_score","chemistry_score","english_score","geography_score"],axis=1)
Y = df.drop(["part_time_job","absence_days","extracurricular_activities","weekly_self_study_hours"],axis=1)
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=45)

# %% [markdown]
# ### The AI Model

# %%
model = LinearRegression()
model.fit(X_train,Y_train)
predicted_data = model.predict(X_test)

# %% [markdown]
# ### MAE,MSE,R2

# %%
MSE = round(mean_squared_error(Y_test,predicted_data))
MAE = round(mean_absolute_error(Y_test,predicted_data))
R2 = round(r2_score(Y_test,predicted_data) * 100)
print(f"MAE: {MAE}")
print(f"MSE: {MSE}")
print(f"R2: {R2}%")
# Out:
# MAE: 3
# MSE: 40
# R2: 72%
